# %%
import tensorflow as tf

# %%
# Load the model
loaded_model = tf.keras.models.load_model('/content/model.keras')

# Verify the model by printing the summary
loaded_model.summary()
input_shape = loaded_model.input_shape
output_shape = loaded_model.output_shape

print("Input shape:", input_shape)
print("Output shape:", output_shape)
# Out:
# Model: "ft_net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)                   │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 6, 6, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         327,936 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output (Dense)                       │ (None, 20)                  │           5,140 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,924,138 (11.15 MB)
#  Trainable params: 333,076 (1.27 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 333,078 (1.27 MB)
# Input shape: (None, 180, 180, 3)
# Output shape: (None, 20)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
# Run inference
img_path = '/content/classification_dataset/basra/0_1000e5a205_png.rf.eb3f7a5ff2c4033c95ac12317baff098.jpg'
img = image.load_img(img_path, target_size=(180, 180))  # Adjust target size
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalize the image
predictions = loaded_model.predict(img_array)

# Process and print the results
predicted_class = np.argmax(predictions, axis=1)
print("Predicted class:", predictions)
print("Predicted class index:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted class: [[1.5362290e-19 4.2038954e-45 1.8168906e-14 2.0101374e-17 6.3028942e-34
#   1.0000000e+00 4.7553360e-33 1.4328974e-24 1.4522155e-27 1.1812950e-14
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 8.1773090e-17 2.4274624e-34
#   1.7507096e-21 0.0000000e+00 1.2174958e-23 8.5022037e-34 2.1860256e-43]]
# Predicted class index: [5]

# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.37-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.7.4)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.37-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 3.4 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.3 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: filetype, python-dotenv, chardet, requests-toolbelt, roboflow
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# Successfully installed chardet-4.0.0 filetype-1.2.0 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.37

# %%
datasets = {
    "Roboflow": [
        {
            "workspace": "yakand",
            "project": "lpr-cckha",
            "version": 1,
            "format": [
                "yolov8",
                "yolov5"
            ],
            "unwanted_classes": [
                3,
                5,
                6,
                7,
                9,
                10,
                11,
                14,
                19,
                20,
                24,
                25,
                27,
                28,
                29,
                31,
                35,
                36,
                39,
                41,
                42
            ],
            "class_map": {
                "0": 0,
                "1": 1,
                "2": 10,
                "3": 11,
                "4": 12,
                "5": 13,
                "6": 14,
                "7": 15,
                "8": 16,
                "9": 17,
                "10": 18,
                "11": 19,
                "12": 2,
                "13": 20,
                "14": 21,
                "15": 22,
                "16": 23,
                "17": 24,
                "18": 25,
                "19": 26,
                "20": 27,
                "21": 28,
                "22": 29,
                "23": 3,
                "24": 30,
                "25": 31,
                "26": 32,
                "27": 33,
                "28": 34,
                "29": 35,
                "30": 36,
                "31": 37,
                "32": 38,
                "33": 39,
                "34": 4,
                "35": 40,
                "36": 41,
                "37": 42,
                "38": 43,
                "39": 44,
                "40": 45,
                "41": 46,
                "42": 47,
                "43": 5,
                "44": 6,
                "45": 7,
                "46": 8,
                "47": 9
            }
        },
        {
            "workspace": "msc-9pkbx",
            "project": "new-zfexd",
            "version": 1,
            "format": [
                "yolov8",
                "yolov5"
            ],
            "unwanted_classes": [
                11,
                13,
                14,
                15,
                17,
                18,
                19,
                21,
                26,
                27,
                30,
                31,
                33,
                34,
                35,
                37,
                40,
                41,
                44,
                46,
                47
            ],
            "class_map": None
        }
    ]
}

# %%
from roboflow import Roboflow
from google.colab import userdata

def download_roboflow_datasets(dataset, rf):
    """Download datasets from Roboflow to local directory."""
    for rf_dataset in datasets["Roboflow"]:  # iterate through Roboflow datasets
      project = rf.workspace(rf_dataset["workspace"]).project(rf_dataset["project"])
      version = project.version(rf_dataset["version"])
      dataset = version.download("yolov5", "./" + rf_dataset["project"] + "/")
      #process_classes("./" + rf_dataset["project"] + "/")

ROBOFLOW_API_KEY = userdata.get("ROBOFLOW_API_KEY")
rf = Roboflow(api_key=ROBOFLOW_API_KEY)

download_roboflow_datasets(datasets, rf)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in ./lpr-cckha/ to yolov5pytorch:: 100%|██████████| 323430/323430 [00:08<00:00, 38912.43it/s]
# Extracting Dataset Version Zip to ./lpr-cckha/ in yolov5pytorch:: 100%|██████████| 18380/18380 [00:02<00:00, 6896.59it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in ./new-zfexd/ to yolov5pytorch:: 100%|██████████| 378130/378130 [00:06<00:00, 58294.43it/s]
# Extracting Dataset Version Zip to ./new-zfexd/ in yolov5pytorch:: 100%|██████████| 20670/20670 [00:02<00:00, 7262.88it/s]

# %%
import os

def process_classes(dataset_dir, unwanted_classes):
    """Filter out classes unrelated to Arabic OCR"""
    dirs = ["train/", "test/", "valid/"]

    for dir in dirs:
        path = dataset_dir + dir + "labels/"
        for label in os.listdir(path):
            with open(path + label, "r") as f:
                lines = f.readlines()
                for i in range(len(lines)):
                    class_id = int(lines[i].split(" ")[0])
                    if class_id not in unwanted_classes:
                        lines[i] = ""

            with open(path + label, "w") as f:
                f.writelines(lines)

process_classes("./lpr-cckha/", datasets["Roboflow"][0]["unwanted_classes"])
process_classes("./new-zfexd/", datasets["Roboflow"][1]["unwanted_classes"])

# %%
import os

def clean_dataset(dataset_dir):
    dirs = ["train/", "test/", "valid/"]
    for dir in dirs:
        path = dataset_dir + dir + "labels/"
        for label in os.listdir(path):
            f = open(path + label, "r")
            lines = f.readlines()
            f.close()
            if len(lines) == 0:
                os.remove(path + label)
                os.remove(dataset_dir + dir + "images/" + label[:-3] + "jpg")



clean_dataset("./lpr-cckha/")
clean_dataset("./new-zfexd/")

# %%
import os

class_map = {
    11: "anbar",
    13: "babel",
    14: "baghdad",
    15: "basra",
    17: "zi-qar",
    18: "diyali",
    19: "dahuk",
    21: "erbil",
    26: "karbala",
    27: "karkuk",
    30: "missan",
    31: "al-masna",
    33: "al-najaf",
    35: "private",
    37: "al-qadissiyah",
    40: "salah-eddine",
    41: "suleimaniyah",
    44: "waset",
    46: "taxi",
    47: "truck"
}

for district in class_map.values():
  os.makedirs(f"./classification_dataset/{district}")

# %%
import cv2
import os

def crop_image(image_path, label_path, class_map):
    # Read the image file
    img = cv2.imread(image_path)
    dh, dw, _ = img.shape

    with open(label_path, "r") as f:
        lines = f.readlines()
        i = 0
        for line in lines:
          class_id, x, y, w, h = map(float, line.strip().split(" "))
          l = int((x - w / 2) * dw)
          r = int((x + w / 2) * dw)
          t = int((y - h / 2) * dh)
          b = int((y + h / 2) * dh)

          if l < 0:
              l = 0
          if r > dw - 1:
              r = dw - 1
          if t < 0:
              t = 0
          if b > dh - 1:
              b = dh - 1

          # Crop the image based on the bounding box
          cropped_img = img[t:b, l:r]

          # Save the cropped image
          cv2.imwrite(f"./classification_dataset/{class_map[int(class_id)]}/{i}_{image_path.split('/')[-1]}", cropped_img)
          i += 1

dirs = ["train/", "test/", "valid/"]
datasets = [("lpr-cckha/", {
    3: "anbar",
    5: "babel",
    6: "baghdad",
    7: "basra",
    9: "zi-qar",
    10: "diyali",
    11: "dahuk",
    14: "erbil",
    19: "karbala",
    20: "karkuk",
    24: "missan",
    25: "al-masna",
    27: "al-najaf",
    28: "ninev",
    29: "private",
    31: "al-qadissiyah",
    35: "salah-eddine",
    36: "suleimaniyah",
    39: "waset",
    41: "taxi",
    42: "truck"

}), ("new-zfexd/", {
        11: "anbar",
        13: "babel",
        14: "baghdad",
        15: "basra",
        17: "zi-qar",
        18: "diyali",
        19: "dahuk",
        21: "erbil",
        26: "karbala",
        27: "karkuk",
        30: "missan",
        31: "al-masna",
        33: "al-najaf",
        34: "ninev",
        35: "private",
        37: "al-qadissiyah",
        40: "salah-eddine",
        41: "suleimaniyah",
        44: "waset",
        46: "taxi",
        47: "truck"
    })]
for dataset, class_map in datasets:
  for dir in dirs:
    path = dataset + dir + "labels/"
    for label in os.listdir(path):
      crop_image(dataset + dir + "images/" + label[:-3] + "jpg", path + label, class_map)

# %%
import tensorflow as tf

train_ds = tf.keras.utils.image_dataset_from_directory(
  "./classification_dataset/",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(180, 180),
  batch_size=32)

val_ds = tf.keras.utils.image_dataset_from_directory(
  "./classification_dataset",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(180, 180),
  batch_size=32)
# Out:
# Found 17618 files belonging to 20 classes.
# Using 14095 files for training.
# Found 17618 files belonging to 20 classes.
# Using 3523 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['al-masna', 'al-najaf', 'al-qadissiyah', 'anbar', 'babel', 'baghdad', 'basra', 'dahuk', 'diyali', 'erbil', 'karbala', 'karkuk', 'missan', 'private', 'salah-eddine', 'suleimaniyah', 'taxi', 'truck', 'waset', 'zi-qar']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
import numpy as np

normalization_layer = tf.keras.layers.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.21217862 0.93702614

# %%
# Load the base model with imagenet weights without top layer
base_model = tf.keras.applications.MobileNetV2(
    include_top=False, weights='imagenet', input_shape=(180, 180, 3))
base_model.trainable = False  # Freeze the base model initially
base_model.summary(show_trainable=True, expand_nested=True)
# Out:
# `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenetv2_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape         ┃      Param # ┃ Connected to        ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer_1          │ (None, 180, 180, 3)  │            0 │ -                   │    -    │
# │ (InputLayer)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ Conv1 (Conv2D)         │ (None, 90, 90, 32)   │          864 │ input_layer_1[0][0] │    N    │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bn_Conv1               │ (None, 90, 90, 32)   │          128 │ Conv1[0][0]         │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ Conv1_relu (ReLU)      │ (None, 90, 90, 32)   │            0 │ bn_Conv1[0][0]      │    -    │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ expanded_conv_depthwi… │ (None, 90, 90, 32)   │          288 │ Conv1_relu[0][0]    │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ expanded_conv_depthwi… │ (None, 90, 90, 32)   │          128 │ expanded_conv_dept… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ expanded_conv_depthwi… │ (None, 90, 90, 32)   │            0 │ expanded_conv_dept… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ expanded_conv_project  │ (None, 90, 90, 16)   │          512 │ expanded_conv_dept… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ expanded_conv_project… │ (None, 90, 90, 16)   │           64 │ expanded_conv_proj… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_expand         │ (None, 90, 90, 96)   │        1,536 │ expanded_conv_proj… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_expand_BN      │ (None, 90, 90, 96)   │          384 │ block_1_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_expand_relu    │ (None, 90, 90, 96)   │            0 │ block_1_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_pad            │ (None, 91, 91, 96)   │            0 │ block_1_expand_rel… │    -    │
# │ (ZeroPadding2D)        │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_depthwise      │ (None, 45, 45, 96)   │          864 │ block_1_pad[0][0]   │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_depthwise_BN   │ (None, 45, 45, 96)   │          384 │ block_1_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_depthwise_relu │ (None, 45, 45, 96)   │            0 │ block_1_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_project        │ (None, 45, 45, 24)   │        2,304 │ block_1_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_1_project_BN     │ (None, 45, 45, 24)   │           96 │ block_1_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_expand         │ (None, 45, 45, 144)  │        3,456 │ block_1_project_BN… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_expand_BN      │ (None, 45, 45, 144)  │          576 │ block_2_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_expand_relu    │ (None, 45, 45, 144)  │            0 │ block_2_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_depthwise      │ (None, 45, 45, 144)  │        1,296 │ block_2_expand_rel… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_depthwise_BN   │ (None, 45, 45, 144)  │          576 │ block_2_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_depthwise_relu │ (None, 45, 45, 144)  │            0 │ block_2_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_project        │ (None, 45, 45, 24)   │        3,456 │ block_2_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_project_BN     │ (None, 45, 45, 24)   │           96 │ block_2_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_2_add (Add)      │ (None, 45, 45, 24)   │            0 │ block_1_project_BN… │    -    │
# │                        │                      │              │ block_2_project_BN… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_expand         │ (None, 45, 45, 144)  │        3,456 │ block_2_add[0][0]   │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_expand_BN      │ (None, 45, 45, 144)  │          576 │ block_3_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_expand_relu    │ (None, 45, 45, 144)  │            0 │ block_3_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_pad            │ (None, 47, 47, 144)  │            0 │ block_3_expand_rel… │    -    │
# │ (ZeroPadding2D)        │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_depthwise      │ (None, 23, 23, 144)  │        1,296 │ block_3_pad[0][0]   │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_depthwise_BN   │ (None, 23, 23, 144)  │          576 │ block_3_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_depthwise_relu │ (None, 23, 23, 144)  │            0 │ block_3_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_project        │ (None, 23, 23, 32)   │        4,608 │ block_3_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_3_project_BN     │ (None, 23, 23, 32)   │          128 │ block_3_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_expand         │ (None, 23, 23, 192)  │        6,144 │ block_3_project_BN… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_expand_BN      │ (None, 23, 23, 192)  │          768 │ block_4_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_expand_relu    │ (None, 23, 23, 192)  │            0 │ block_4_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_depthwise      │ (None, 23, 23, 192)  │        1,728 │ block_4_expand_rel… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_depthwise_BN   │ (None, 23, 23, 192)  │          768 │ block_4_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_depthwise_relu │ (None, 23, 23, 192)  │            0 │ block_4_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_project        │ (None, 23, 23, 32)   │        6,144 │ block_4_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_project_BN     │ (None, 23, 23, 32)   │          128 │ block_4_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_4_add (Add)      │ (None, 23, 23, 32)   │            0 │ block_3_project_BN… │    -    │
# │                        │                      │              │ block_4_project_BN… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_expand         │ (None, 23, 23, 192)  │        6,144 │ block_4_add[0][0]   │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_expand_BN      │ (None, 23, 23, 192)  │          768 │ block_5_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_expand_relu    │ (None, 23, 23, 192)  │            0 │ block_5_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_depthwise      │ (None, 23, 23, 192)  │        1,728 │ block_5_expand_rel… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_depthwise_BN   │ (None, 23, 23, 192)  │          768 │ block_5_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_depthwise_relu │ (None, 23, 23, 192)  │            0 │ block_5_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_project        │ (None, 23, 23, 32)   │        6,144 │ block_5_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_project_BN     │ (None, 23, 23, 32)   │          128 │ block_5_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_5_add (Add)      │ (None, 23, 23, 32)   │            0 │ block_4_add[0][0],  │    -    │
# │                        │                      │              │ block_5_project_BN… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_expand         │ (None, 23, 23, 192)  │        6,144 │ block_5_add[0][0]   │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_expand_BN      │ (None, 23, 23, 192)  │          768 │ block_6_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_expand_relu    │ (None, 23, 23, 192)  │            0 │ block_6_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_pad            │ (None, 25, 25, 192)  │            0 │ block_6_expand_rel… │    -    │
# │ (ZeroPadding2D)        │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_depthwise      │ (None, 12, 12, 192)  │        1,728 │ block_6_pad[0][0]   │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_depthwise_BN   │ (None, 12, 12, 192)  │          768 │ block_6_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_depthwise_relu │ (None, 12, 12, 192)  │            0 │ block_6_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_project        │ (None, 12, 12, 64)   │       12,288 │ block_6_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_6_project_BN     │ (None, 12, 12, 64)   │          256 │ block_6_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_expand         │ (None, 12, 12, 384)  │       24,576 │ block_6_project_BN… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_expand_BN      │ (None, 12, 12, 384)  │        1,536 │ block_7_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_expand_relu    │ (None, 12, 12, 384)  │            0 │ block_7_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_depthwise      │ (None, 12, 12, 384)  │        3,456 │ block_7_expand_rel… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_depthwise_BN   │ (None, 12, 12, 384)  │        1,536 │ block_7_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_depthwise_relu │ (None, 12, 12, 384)  │            0 │ block_7_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_project        │ (None, 12, 12, 64)   │       24,576 │ block_7_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_project_BN     │ (None, 12, 12, 64)   │          256 │ block_7_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_7_add (Add)      │ (None, 12, 12, 64)   │            0 │ block_6_project_BN… │    -    │
# │                        │                      │              │ block_7_project_BN… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_expand         │ (None, 12, 12, 384)  │       24,576 │ block_7_add[0][0]   │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_expand_BN      │ (None, 12, 12, 384)  │        1,536 │ block_8_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_expand_relu    │ (None, 12, 12, 384)  │            0 │ block_8_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_depthwise      │ (None, 12, 12, 384)  │        3,456 │ block_8_expand_rel… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_depthwise_BN   │ (None, 12, 12, 384)  │        1,536 │ block_8_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_depthwise_relu │ (None, 12, 12, 384)  │            0 │ block_8_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_project        │ (None, 12, 12, 64)   │       24,576 │ block_8_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_project_BN     │ (None, 12, 12, 64)   │          256 │ block_8_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_8_add (Add)      │ (None, 12, 12, 64)   │            0 │ block_7_add[0][0],  │    -    │
# │                        │                      │              │ block_8_project_BN… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_expand         │ (None, 12, 12, 384)  │       24,576 │ block_8_add[0][0]   │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_expand_BN      │ (None, 12, 12, 384)  │        1,536 │ block_9_expand[0][… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_expand_relu    │ (None, 12, 12, 384)  │            0 │ block_9_expand_BN[… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_depthwise      │ (None, 12, 12, 384)  │        3,456 │ block_9_expand_rel… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_depthwise_BN   │ (None, 12, 12, 384)  │        1,536 │ block_9_depthwise[… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_depthwise_relu │ (None, 12, 12, 384)  │            0 │ block_9_depthwise_… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_project        │ (None, 12, 12, 64)   │       24,576 │ block_9_depthwise_… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_project_BN     │ (None, 12, 12, 64)   │          256 │ block_9_project[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_9_add (Add)      │ (None, 12, 12, 64)   │            0 │ block_8_add[0][0],  │    -    │
# │                        │                      │              │ block_9_project_BN… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_expand        │ (None, 12, 12, 384)  │       24,576 │ block_9_add[0][0]   │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_expand_BN     │ (None, 12, 12, 384)  │        1,536 │ block_10_expand[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_expand_relu   │ (None, 12, 12, 384)  │            0 │ block_10_expand_BN… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_depthwise     │ (None, 12, 12, 384)  │        3,456 │ block_10_expand_re… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_depthwise_BN  │ (None, 12, 12, 384)  │        1,536 │ block_10_depthwise… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_depthwise_re… │ (None, 12, 12, 384)  │            0 │ block_10_depthwise… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_project       │ (None, 12, 12, 96)   │       36,864 │ block_10_depthwise… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_10_project_BN    │ (None, 12, 12, 96)   │          384 │ block_10_project[0… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_expand        │ (None, 12, 12, 576)  │       55,296 │ block_10_project_B… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_expand_BN     │ (None, 12, 12, 576)  │        2,304 │ block_11_expand[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_expand_relu   │ (None, 12, 12, 576)  │            0 │ block_11_expand_BN… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_depthwise     │ (None, 12, 12, 576)  │        5,184 │ block_11_expand_re… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_depthwise_BN  │ (None, 12, 12, 576)  │        2,304 │ block_11_depthwise… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_depthwise_re… │ (None, 12, 12, 576)  │            0 │ block_11_depthwise… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_project       │ (None, 12, 12, 96)   │       55,296 │ block_11_depthwise… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_project_BN    │ (None, 12, 12, 96)   │          384 │ block_11_project[0… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_11_add (Add)     │ (None, 12, 12, 96)   │            0 │ block_10_project_B… │    -    │
# │                        │                      │              │ block_11_project_B… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_expand        │ (None, 12, 12, 576)  │       55,296 │ block_11_add[0][0]  │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_expand_BN     │ (None, 12, 12, 576)  │        2,304 │ block_12_expand[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_expand_relu   │ (None, 12, 12, 576)  │            0 │ block_12_expand_BN… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_depthwise     │ (None, 12, 12, 576)  │        5,184 │ block_12_expand_re… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_depthwise_BN  │ (None, 12, 12, 576)  │        2,304 │ block_12_depthwise… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_depthwise_re… │ (None, 12, 12, 576)  │            0 │ block_12_depthwise… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_project       │ (None, 12, 12, 96)   │       55,296 │ block_12_depthwise… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_project_BN    │ (None, 12, 12, 96)   │          384 │ block_12_project[0… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_12_add (Add)     │ (None, 12, 12, 96)   │            0 │ block_11_add[0][0], │    -    │
# │                        │                      │              │ block_12_project_B… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_expand        │ (None, 12, 12, 576)  │       55,296 │ block_12_add[0][0]  │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_expand_BN     │ (None, 12, 12, 576)  │        2,304 │ block_13_expand[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_expand_relu   │ (None, 12, 12, 576)  │            0 │ block_13_expand_BN… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_pad           │ (None, 13, 13, 576)  │            0 │ block_13_expand_re… │    -    │
# │ (ZeroPadding2D)        │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_depthwise     │ (None, 6, 6, 576)    │        5,184 │ block_13_pad[0][0]  │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_depthwise_BN  │ (None, 6, 6, 576)    │        2,304 │ block_13_depthwise… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_depthwise_re… │ (None, 6, 6, 576)    │            0 │ block_13_depthwise… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_project       │ (None, 6, 6, 160)    │       92,160 │ block_13_depthwise… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_13_project_BN    │ (None, 6, 6, 160)    │          640 │ block_13_project[0… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_expand        │ (None, 6, 6, 960)    │      153,600 │ block_13_project_B… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_expand_BN     │ (None, 6, 6, 960)    │        3,840 │ block_14_expand[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_expand_relu   │ (None, 6, 6, 960)    │            0 │ block_14_expand_BN… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_depthwise     │ (None, 6, 6, 960)    │        8,640 │ block_14_expand_re… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_depthwise_BN  │ (None, 6, 6, 960)    │        3,840 │ block_14_depthwise… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_depthwise_re… │ (None, 6, 6, 960)    │            0 │ block_14_depthwise… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_project       │ (None, 6, 6, 160)    │      153,600 │ block_14_depthwise… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_project_BN    │ (None, 6, 6, 160)    │          640 │ block_14_project[0… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_14_add (Add)     │ (None, 6, 6, 160)    │            0 │ block_13_project_B… │    -    │
# │                        │                      │              │ block_14_project_B… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_expand        │ (None, 6, 6, 960)    │      153,600 │ block_14_add[0][0]  │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_expand_BN     │ (None, 6, 6, 960)    │        3,840 │ block_15_expand[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_expand_relu   │ (None, 6, 6, 960)    │            0 │ block_15_expand_BN… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_depthwise     │ (None, 6, 6, 960)    │        8,640 │ block_15_expand_re… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_depthwise_BN  │ (None, 6, 6, 960)    │        3,840 │ block_15_depthwise… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_depthwise_re… │ (None, 6, 6, 960)    │            0 │ block_15_depthwise… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_project       │ (None, 6, 6, 160)    │      153,600 │ block_15_depthwise… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_project_BN    │ (None, 6, 6, 160)    │          640 │ block_15_project[0… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_15_add (Add)     │ (None, 6, 6, 160)    │            0 │ block_14_add[0][0], │    -    │
# │                        │                      │              │ block_15_project_B… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_expand        │ (None, 6, 6, 960)    │      153,600 │ block_15_add[0][0]  │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_expand_BN     │ (None, 6, 6, 960)    │        3,840 │ block_16_expand[0]… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_expand_relu   │ (None, 6, 6, 960)    │            0 │ block_16_expand_BN… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_depthwise     │ (None, 6, 6, 960)    │        8,640 │ block_16_expand_re… │    N    │
# │ (DepthwiseConv2D)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_depthwise_BN  │ (None, 6, 6, 960)    │        3,840 │ block_16_depthwise… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_depthwise_re… │ (None, 6, 6, 960)    │            0 │ block_16_depthwise… │    -    │
# │ (ReLU)                 │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_project       │ (None, 6, 6, 320)    │      307,200 │ block_16_depthwise… │    N    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ block_16_project_BN    │ (None, 6, 6, 320)    │        1,280 │ block_16_project[0… │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ Conv_1 (Conv2D)        │ (None, 6, 6, 1280)   │      409,600 │ block_16_project_B… │    N    │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ Conv_1_bn              │ (None, 6, 6, 1280)   │        5,120 │ Conv_1[0][0]        │    N    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ out_relu (ReLU)        │ (None, 6, 6, 1280)   │            0 │ Conv_1_bn[0][0]     │    -    │
# └────────────────────────┴──────────────────────┴──────────────┴─────────────────────┴─────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
def preprocess(image, label):
  # ... (your existing preprocessing steps)
  # One-hot encode the labels
  one_hot_label = tf.keras.utils.to_categorical(label, num_classes=20)  # Assuming you have 20 classes
  return image, one_hot_label

# Apply the preprocessing function to your training dataset
train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)

# %%
# Define input
input = tf.keras.Input(shape=(180, 180, 3), name="input")
# Add new layers on top of the model
x = base_model(input, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.15)(x) # optional for your own experiments
x = tf.keras.layers.Dense(256, activation='relu')(x)
predictions = tf.keras.layers.Dense(20, activation='softmax', name="output")(x)
model = tf.keras.models.Model(inputs=input, outputs=predictions, name="ft_net")
model.summary(show_trainable=True, expand_nested=True)
# Out:
# Model: "ft_net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input (InputLayer)                  │ (None, 180, 180, 3)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ mobilenetv2_1.00_224 (Functional)   │ (None, 6, 6, 1280)           │     2,257,984 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ input_layer_1 (InputLayer)     │ (None, 180, 180, 3)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ Conv1 (Conv2D)                 │ (None, 90, 90, 32)           │           864 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ bn_Conv1 (BatchNormalization)  │ (None, 90, 90, 32)           │           128 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ Conv1_relu (ReLU)              │ (None, 90, 90, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ expanded_conv_depthwise        │ (None, 90, 90, 32)           │           288 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ expanded_conv_depthwise_BN     │ (None, 90, 90, 32)           │           128 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ expanded_conv_depthwise_relu   │ (None, 90, 90, 32)           │             0 │    -    │
# │ (ReLU)                              │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ expanded_conv_project (Conv2D) │ (None, 90, 90, 16)           │           512 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ expanded_conv_project_BN       │ (None, 90, 90, 16)           │            64 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_expand (Conv2D)        │ (None, 90, 90, 96)           │         1,536 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_expand_BN              │ (None, 90, 90, 96)           │           384 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_expand_relu (ReLU)     │ (None, 90, 90, 96)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_pad (ZeroPadding2D)    │ (None, 91, 91, 96)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_depthwise              │ (None, 45, 45, 96)           │           864 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_depthwise_BN           │ (None, 45, 45, 96)           │           384 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_depthwise_relu (ReLU)  │ (None, 45, 45, 96)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_project (Conv2D)       │ (None, 45, 45, 24)           │         2,304 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_1_project_BN             │ (None, 45, 45, 24)           │            96 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_expand (Conv2D)        │ (None, 45, 45, 144)          │         3,456 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_expand_BN              │ (None, 45, 45, 144)          │           576 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_expand_relu (ReLU)     │ (None, 45, 45, 144)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_depthwise              │ (None, 45, 45, 144)          │         1,296 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_depthwise_BN           │ (None, 45, 45, 144)          │           576 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_depthwise_relu (ReLU)  │ (None, 45, 45, 144)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_project (Conv2D)       │ (None, 45, 45, 24)           │         3,456 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_project_BN             │ (None, 45, 45, 24)           │            96 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_2_add (Add)              │ (None, 45, 45, 24)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_expand (Conv2D)        │ (None, 45, 45, 144)          │         3,456 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_expand_BN              │ (None, 45, 45, 144)          │           576 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_expand_relu (ReLU)     │ (None, 45, 45, 144)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_pad (ZeroPadding2D)    │ (None, 47, 47, 144)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_depthwise              │ (None, 23, 23, 144)          │         1,296 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_depthwise_BN           │ (None, 23, 23, 144)          │           576 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_depthwise_relu (ReLU)  │ (None, 23, 23, 144)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_project (Conv2D)       │ (None, 23, 23, 32)           │         4,608 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_3_project_BN             │ (None, 23, 23, 32)           │           128 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_expand (Conv2D)        │ (None, 23, 23, 192)          │         6,144 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_expand_BN              │ (None, 23, 23, 192)          │           768 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_expand_relu (ReLU)     │ (None, 23, 23, 192)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_depthwise              │ (None, 23, 23, 192)          │         1,728 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_depthwise_BN           │ (None, 23, 23, 192)          │           768 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_depthwise_relu (ReLU)  │ (None, 23, 23, 192)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_project (Conv2D)       │ (None, 23, 23, 32)           │         6,144 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_project_BN             │ (None, 23, 23, 32)           │           128 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_4_add (Add)              │ (None, 23, 23, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_expand (Conv2D)        │ (None, 23, 23, 192)          │         6,144 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_expand_BN              │ (None, 23, 23, 192)          │           768 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_expand_relu (ReLU)     │ (None, 23, 23, 192)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_depthwise              │ (None, 23, 23, 192)          │         1,728 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_depthwise_BN           │ (None, 23, 23, 192)          │           768 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_depthwise_relu (ReLU)  │ (None, 23, 23, 192)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_project (Conv2D)       │ (None, 23, 23, 32)           │         6,144 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_project_BN             │ (None, 23, 23, 32)           │           128 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_5_add (Add)              │ (None, 23, 23, 32)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_expand (Conv2D)        │ (None, 23, 23, 192)          │         6,144 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_expand_BN              │ (None, 23, 23, 192)          │           768 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_expand_relu (ReLU)     │ (None, 23, 23, 192)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_pad (ZeroPadding2D)    │ (None, 25, 25, 192)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_depthwise              │ (None, 12, 12, 192)          │         1,728 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_depthwise_BN           │ (None, 12, 12, 192)          │           768 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_depthwise_relu (ReLU)  │ (None, 12, 12, 192)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_project (Conv2D)       │ (None, 12, 12, 64)           │        12,288 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_6_project_BN             │ (None, 12, 12, 64)           │           256 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_expand (Conv2D)        │ (None, 12, 12, 384)          │        24,576 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_expand_BN              │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_expand_relu (ReLU)     │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_depthwise              │ (None, 12, 12, 384)          │         3,456 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_depthwise_BN           │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_depthwise_relu (ReLU)  │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_project (Conv2D)       │ (None, 12, 12, 64)           │        24,576 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_project_BN             │ (None, 12, 12, 64)           │           256 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_7_add (Add)              │ (None, 12, 12, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_expand (Conv2D)        │ (None, 12, 12, 384)          │        24,576 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_expand_BN              │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_expand_relu (ReLU)     │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_depthwise              │ (None, 12, 12, 384)          │         3,456 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_depthwise_BN           │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_depthwise_relu (ReLU)  │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_project (Conv2D)       │ (None, 12, 12, 64)           │        24,576 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_project_BN             │ (None, 12, 12, 64)           │           256 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_8_add (Add)              │ (None, 12, 12, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_expand (Conv2D)        │ (None, 12, 12, 384)          │        24,576 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_expand_BN              │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_expand_relu (ReLU)     │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_depthwise              │ (None, 12, 12, 384)          │         3,456 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_depthwise_BN           │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_depthwise_relu (ReLU)  │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_project (Conv2D)       │ (None, 12, 12, 64)           │        24,576 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_project_BN             │ (None, 12, 12, 64)           │           256 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_9_add (Add)              │ (None, 12, 12, 64)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_expand (Conv2D)       │ (None, 12, 12, 384)          │        24,576 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_expand_BN             │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_expand_relu (ReLU)    │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_depthwise             │ (None, 12, 12, 384)          │         3,456 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_depthwise_BN          │ (None, 12, 12, 384)          │         1,536 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_depthwise_relu (ReLU) │ (None, 12, 12, 384)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_project (Conv2D)      │ (None, 12, 12, 96)           │        36,864 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_10_project_BN            │ (None, 12, 12, 96)           │           384 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_expand (Conv2D)       │ (None, 12, 12, 576)          │        55,296 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_expand_BN             │ (None, 12, 12, 576)          │         2,304 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_expand_relu (ReLU)    │ (None, 12, 12, 576)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_depthwise             │ (None, 12, 12, 576)          │         5,184 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_depthwise_BN          │ (None, 12, 12, 576)          │         2,304 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_depthwise_relu (ReLU) │ (None, 12, 12, 576)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_project (Conv2D)      │ (None, 12, 12, 96)           │        55,296 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_project_BN            │ (None, 12, 12, 96)           │           384 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_11_add (Add)             │ (None, 12, 12, 96)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_expand (Conv2D)       │ (None, 12, 12, 576)          │        55,296 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_expand_BN             │ (None, 12, 12, 576)          │         2,304 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_expand_relu (ReLU)    │ (None, 12, 12, 576)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_depthwise             │ (None, 12, 12, 576)          │         5,184 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_depthwise_BN          │ (None, 12, 12, 576)          │         2,304 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_depthwise_relu (ReLU) │ (None, 12, 12, 576)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_project (Conv2D)      │ (None, 12, 12, 96)           │        55,296 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_project_BN            │ (None, 12, 12, 96)           │           384 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_12_add (Add)             │ (None, 12, 12, 96)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_expand (Conv2D)       │ (None, 12, 12, 576)          │        55,296 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_expand_BN             │ (None, 12, 12, 576)          │         2,304 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_expand_relu (ReLU)    │ (None, 12, 12, 576)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_pad (ZeroPadding2D)   │ (None, 13, 13, 576)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_depthwise             │ (None, 6, 6, 576)            │         5,184 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_depthwise_BN          │ (None, 6, 6, 576)            │         2,304 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_depthwise_relu (ReLU) │ (None, 6, 6, 576)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_project (Conv2D)      │ (None, 6, 6, 160)            │        92,160 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_13_project_BN            │ (None, 6, 6, 160)            │           640 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_expand (Conv2D)       │ (None, 6, 6, 960)            │       153,600 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_expand_BN             │ (None, 6, 6, 960)            │         3,840 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_expand_relu (ReLU)    │ (None, 6, 6, 960)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_depthwise             │ (None, 6, 6, 960)            │         8,640 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_depthwise_BN          │ (None, 6, 6, 960)            │         3,840 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_depthwise_relu (ReLU) │ (None, 6, 6, 960)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_project (Conv2D)      │ (None, 6, 6, 160)            │       153,600 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_project_BN            │ (None, 6, 6, 160)            │           640 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_14_add (Add)             │ (None, 6, 6, 160)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_expand (Conv2D)       │ (None, 6, 6, 960)            │       153,600 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_expand_BN             │ (None, 6, 6, 960)            │         3,840 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_expand_relu (ReLU)    │ (None, 6, 6, 960)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_depthwise             │ (None, 6, 6, 960)            │         8,640 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_depthwise_BN          │ (None, 6, 6, 960)            │         3,840 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_depthwise_relu (ReLU) │ (None, 6, 6, 960)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_project (Conv2D)      │ (None, 6, 6, 160)            │       153,600 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_project_BN            │ (None, 6, 6, 160)            │           640 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_15_add (Add)             │ (None, 6, 6, 160)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_expand (Conv2D)       │ (None, 6, 6, 960)            │       153,600 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_expand_BN             │ (None, 6, 6, 960)            │         3,840 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_expand_relu (ReLU)    │ (None, 6, 6, 960)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_depthwise             │ (None, 6, 6, 960)            │         8,640 │    N    │
# │ (DepthwiseConv2D)                   │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_depthwise_BN          │ (None, 6, 6, 960)            │         3,840 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_depthwise_relu (ReLU) │ (None, 6, 6, 960)            │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_project (Conv2D)      │ (None, 6, 6, 320)            │       307,200 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ block_16_project_BN            │ (None, 6, 6, 320)            │         1,280 │    N    │
# │ (BatchNormalization)                │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ Conv_1 (Conv2D)                │ (None, 6, 6, 1280)           │       409,600 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ Conv_1_bn (BatchNormalization) │ (None, 6, 6, 1280)           │         5,120 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │    └ out_relu (ReLU)                │ (None, 6, 6, 1280)           │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ global_average_pooling2d_1          │ (None, 1280)                 │             0 │    -    │
# │ (GlobalAveragePooling2D)            │                              │               │         │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dropout_1 (Dropout)                 │ (None, 1280)                 │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense_1 (Dense)                     │ (None, 256)                  │       327,936 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ output (Dense)                      │ (None, 20)                   │         5,140 │    Y    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 2,591,060 (9.88 MB)
#  Trainable params: 333,076 (1.27 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
base_model = model.layers[1]
# Unfreeze the last layers
for layer in base_model.layers[-5:]:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        print("This layer is a batch normalization layer")
    else:
        layer.trainable = True
# Out:
# This layer is a batch normalization layer
# This layer is a batch normalization layer

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0015),
      loss='categorical_crossentropy', metrics=['accuracy'])

# %%
fit_history_t = None

NUM_TRANSF_EPOCHS = 40
fit_history_t = model.fit(train_ds, epochs=NUM_TRANSF_EPOCHS,
     validation_data=val_ds)
loss, accuracy = model.evaluate(val_ds)
model.save("./model.keras")
#concatenated_history = concatenate_histories(fit_history_t,
#      fit_history_retr)
#plot_training_history("Transferlearn with HIDDEN=256",
#      concatenated_history)
# Out:
# Epoch 1/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.2965 - loss: 2.8192 - val_accuracy: 0.3287 - val_loss: 2.4690
# Epoch 2/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3279 - loss: 2.4877 - val_accuracy: 0.3287 - val_loss: 2.4734
# Epoch 3/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3266 - loss: 2.4761 - val_accuracy: 0.3287 - val_loss: 2.4690
# Epoch 4/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3241 - loss: 2.4770 - val_accuracy: 0.3287 - val_loss: 2.4562
# Epoch 5/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3272 - loss: 2.4756 - val_accuracy: 0.3287 - val_loss: 2.4632
# Epoch 6/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3276 - loss: 2.4709 - val_accuracy: 0.3287 - val_loss: 2.4892
# Epoch 7/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3350 - loss: 2.4502 - val_accuracy: 0.3287 - val_loss: 2.4590
# Epoch 8/40
# 441/441 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.3284 - loss: 2.4630 - val_accuracy: 0.3287 - val_loss: 2.4762
# Epoch 9/40
# 156/441 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.3360 - loss: 2.4579
